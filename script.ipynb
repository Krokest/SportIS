-- %% [markdown]
-- # [SportIS]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [SportIS]    Script Date: 23.12.2024 1:10:53 ******/
CREATE DATABASE [SportIS]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'SportIS', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\SportIS.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'SportIS_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\SportIS_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [SportIS] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [SportIS].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [SportIS] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [SportIS] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [SportIS] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [SportIS] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [SportIS] SET ARITHABORT OFF 
GO
ALTER DATABASE [SportIS] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [SportIS] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [SportIS] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [SportIS] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [SportIS] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [SportIS] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [SportIS] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [SportIS] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [SportIS] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [SportIS] SET  DISABLE_BROKER 
GO
ALTER DATABASE [SportIS] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [SportIS] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [SportIS] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [SportIS] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [SportIS] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [SportIS] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [SportIS] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [SportIS] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [SportIS] SET  MULTI_USER 
GO
ALTER DATABASE [SportIS] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [SportIS] SET DB_CHAINING OFF 
GO
ALTER DATABASE [SportIS] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [SportIS] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [SportIS] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [SportIS] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [SportIS] SET QUERY_STORE = ON
GO
ALTER DATABASE [SportIS] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Clients]

-- %%
USE [SportIS]
GO

-- %%
/****** Object:  Table [dbo].[Clients]    Script Date: 23.12.2024 1:10:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Clients](
	[Client_ID] [int] IDENTITY(1,1) NOT NULL,
	[Last_Name] [nchar](255) NOT NULL,
	[First_Name] [nchar](255) NOT NULL,
	[Membership_Type] [nchar](255) NOT NULL,
	[Contact_Details] [nchar](255) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Client_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Employees]

-- %%
/****** Object:  Table [dbo].[Employees]    Script Date: 23.12.2024 1:10:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Employees](
	[Employee_ID] [int] IDENTITY(1,1) NOT NULL,
	[Last_Name] [nchar](255) NOT NULL,
	[First_Name] [nchar](255) NOT NULL,
	[Position] [nchar](255) NOT NULL,
	[Contact_Details] [nchar](255) NOT NULL,
	[Working_Hours] [nchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[Employee_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Equipment]

-- %%
/****** Object:  Table [dbo].[Equipment]    Script Date: 23.12.2024 1:10:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Equipment](
	[Equipment_ID] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nchar](255) NOT NULL,
	[Category] [nchar](255) NOT NULL,
	[Purchase_Date] [date] NOT NULL,
	[Condition] [nchar](255) NOT NULL,
	[Serial_Number] [nchar](255) NOT NULL,
	[Location_ID] [int] NOT NULL,
	[Price] [decimal](10, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Equipment_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Locations]

-- %%
/****** Object:  Table [dbo].[Locations]    Script Date: 23.12.2024 1:10:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Locations](
	[Location_ID] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nchar](255) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Location_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Maintenance]

-- %%
/****** Object:  Table [dbo].[Maintenance]    Script Date: 23.12.2024 1:10:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Maintenance](
	[Maintenance_ID] [int] IDENTITY(1,1) NOT NULL,
	[Equipment_ID] [int] NOT NULL,
	[Date_of_Maintenance] [date] NOT NULL,
	[Type_of_Maintenance] [nchar](255) NOT NULL,
	[Notes] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[Maintenance_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usage]

-- %%
/****** Object:  Table [dbo].[Usage]    Script Date: 23.12.2024 1:10:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usage](
	[Usage_ID] [int] IDENTITY(1,1) NOT NULL,
	[Equipment_ID] [int] NOT NULL,
	[Client_ID] [int] NOT NULL,
	[Employee_ID] [int] NOT NULL,
	[Start_Date] [datetime] NOT NULL,
	[End_Date] [datetime] NULL,
	[Condition] [nchar](255) NOT NULL,
	[Session_Duration] [int] NOT NULL,
	[Notes] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[Usage_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Equipment__Locat__3B75D760]

-- %%
ALTER TABLE [dbo].[Equipment]  WITH CHECK ADD FOREIGN KEY([Location_ID])
REFERENCES [dbo].[Locations] ([Location_ID])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__Maintenan__Equip__403A8C7D]

-- %%
ALTER TABLE [dbo].[Maintenance]  WITH CHECK ADD FOREIGN KEY([Equipment_ID])
REFERENCES [dbo].[Equipment] ([Equipment_ID])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__Usage__Client_ID__440B1D61]

-- %%
ALTER TABLE [dbo].[Usage]  WITH CHECK ADD FOREIGN KEY([Client_ID])
REFERENCES [dbo].[Clients] ([Client_ID])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__Usage__Employee___44FF419A]

-- %%
ALTER TABLE [dbo].[Usage]  WITH CHECK ADD FOREIGN KEY([Employee_ID])
REFERENCES [dbo].[Employees] ([Employee_ID])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__Usage__Equipment__4316F928]

-- %%
ALTER TABLE [dbo].[Usage]  WITH CHECK ADD FOREIGN KEY([Equipment_ID])
REFERENCES [dbo].[Equipment] ([Equipment_ID])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [SportIS]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [SportIS] SET  READ_WRITE 
GO
